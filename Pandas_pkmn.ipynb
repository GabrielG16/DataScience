# %% [markdown]
# # Carregando dados em dataframes (formato de objeto pandas)

# %%
import pandas as pd
df = pd.read_csv('Pokemon.csv') #Carrega o csv
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df)
print(df.head(5)) #Os 5 primeiros 
print(df.tail(5)) # Os 5 últimos
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# # Leitura de dados

# %%
"""
#Leitura de cabeçalhos
print(df.columns)
#Leitura de coluna específica
print(df['Name'])
#Leitura de linha específica
print(df.iloc[1:4])
##Leitura de uma posição específica (linha, coluna) (método iloc)
print(df.iloc[2,1]) #linha, coluna
#Percorrendo a planilha linha a linha podendo filtrar os elementos de coluna (gerador iterrows)
for indice, linha in df.iterrows():
    print(f'Índice: {indice} {linha[1]}')
#Buscando linhas que contenham informações específicas nas colunas (loc)
df.loc[df['Legendary']==True]
"""
df.loc[df['Legendary']==True].head(10)
#Medidas de estatística descritiva
#df.describe()
#Reorganizar valores de acordo com colunas específicas
#df.sort_values('Speed', ascending = False)
#df.sort_values(['Type 1', 'Attack'], ascending = [True, False]) # Ordena os valores em relação a mais de um critério.
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150  MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 262  243               Raikou  Electric       NaN    580   90      85
# 263  244                Entei      Fire       NaN    580  115     115
# 264  245              Suicune     Water       NaN    580  100      75
# 269  249                Lugia   Psychic    Flying    680  106      90
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# ...

# %% [markdown]
# # Modificando dados

# %%
#Adicionando uma nova coluna
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Speed']
#print(type(df))
df['Total'] =  df.iloc[:,4:10].sum(axis=1)
#df.head(5)

#Excluindo uma coluna
#df = df.drop(columns=['Total'])

#Reordenamento de colunas
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Generation  Type 2  Type 2  Speed  \
# 0  1              Bulbasaur  Grass           1  Poison  Poison     45
# 1  2                Ivysaur  Grass           1  Poison  Poison     60
# 2  3               Venusaur  Grass           1  Poison  Poison     80
# 3  3  VenusaurMega Venusaur  Grass           1  Poison  Poison     80
# 4  4             Charmander   Fire           1     NaN     NaN     65
#
#    Generation  Type 2  Type 2  Legendary  Total  HP  Attack  Defense
# 0           1  Poison  Poison      False    864  45      49       49
# 1           1  Poison  Poison      False   1095  60      62       63
# 2           1  Poison  Poison      False   1415  80      82       83
# 3           1  Poison  Poison      False   1715  80     100      123
# 4           1     NaN     NaN      False    797  39      52       43

# %% [markdown]
# # Exportando (CSV, Excel, etc)

# %%
df.to_excel('modified.xlsx', index=False)

# %% [markdown]
# # Filtragem com base em múltiplas condições

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Legendary'] == True)] # Condicionais entre parenteses separadamente
df.loc[(df['Type 1'] == 'Fire') | (df['Type 2'] == 'Flying')] #| = OU
new_df =  df.loc[(df['Type 1'] == 'Fire') & (df['Legendary'] == True)] #No entanto, os indices permanecem com a numeração da tabela original
new_df.reset_index(drop=True, inplace=True) #reseta os indices ordena-los novamente na nova planilha filtrada. 
#Drop = True retira os indices anteriores que ficariam como uma nova coluna e o inplace = True realiza a mudança no doc original
df.loc[df['Name'].str.contains('Mega')] # Filtrar elementos que contenham na coluna nome a palavra 'Mega'
df.loc[~df['Name'].str.contains('Mega')] # Filtrar elementos que NÃO contenham na coluna nome a palavra 'Mega'
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %% [markdown]
# # Mudanças condicionais

# %%
df.loc[df['Type 1'] == 'Grass', 'Type 1'] = 'Grass' # O primeiro parametro delimita os elementos que serão filtrados,
                                                    # o segundo parâmetro indica quais colunas (lista) dos elementos filtrados serão
                                                    # afetadas pela mudança.
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Agrupamentos de dados

# %%
df.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)
df.groupby(['Type 1']).count()['#']
df.groupby(['Type 1', 'Type 2']).count()['#']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: #, Length: 136, dtype: int64

# %% [markdown]
# # Trabalhando com grande quantidade de dados

# %%
"""
"""
new_df = pd.DataFrame(columns = df.columns) # cria uma nova planilha vazia, setando as mesmas colunas do df ja criado
#É possível trazer apenas pedaços dos dados para trabalhar por vez
for df in pd.read_csv('Pokemon.csv', chunksize=5):
    #print("#####\t CHUNK DF \t #####")
    #print(df)
    results = df.groupby(['Type 1']).count()['#']
    new_df = pd.concat([new_df, results])
print(new_df)
# Out:
#            0    # Attack Defense Generation   HP Legendary Name Sp. Atk  \
# Fire     1.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Grass    4.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Fire     4.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Water    1.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Bug      2.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# ...      ...  ...    ...     ...        ...  ...       ...  ...     ...
# Fairy    1.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Flying   2.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Fire     1.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Psychic  2.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
# Rock     2.0  NaN    NaN     NaN        NaN  NaN       NaN  NaN     NaN
#
#         Sp. Def Speed Total Type 1 Type 2
# Fire        NaN   NaN   NaN    NaN    NaN
# ...

# %%
name = 'Lizz'
print(name[0:2])
# Out:
# Li

# %%
print(name[0:2])
